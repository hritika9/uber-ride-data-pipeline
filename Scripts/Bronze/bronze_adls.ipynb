# %%
import pandas as pd

files = [
{"file":"map_cities"},
{"file":"map_cancellation_reasons"},
{"file":"map_payment_methods"},
{"file":"map_ride_statuses"},
{"file":"map_vehicle_makes"},
{"file":"map_vehicle_types"}
]

for i in files:
    url = f"https://dluberprojectgdev.blob.core.windows.net/raw/ingestion/{i['file']}.json?sp=r&st=2026-06-17T13:50:44Z&se=2026-06-29T22:05:44Z&spr=https&sv=2026-02-06&sr=c&sig=G2Cm66sHNjUUPM9zWTFGhKlV7ufdiXUZ4KVGexE7d5U%3D"

    df = pd.read_json(url)
    df_spark = spark.createDataFrame(df)
    #writing data to bronze layer
    df_spark.write.format("delta")\
                   .mode("overwrite")\
                   .option("overwriteSchema", "true")\
                   .saveAsTable(f"uber.bronze_new.{i['file']}")

# %%
url = f"https://dluberprojectgdev.blob.core.windows.net/raw/ingestion/bulk_rides.json?sp=r&st=2026-06-17T13:50:44Z&se=2026-06-29T22:05:44Z&spr=https&sv=2026-02-06&sr=c&sig=G2Cm66sHNjUUPM9zWTFGhKlV7ufdiXUZ4KVGexE7d5U%3D"

df = pd.read_json(url)
df_spark = spark.createDataframe(df)
if not spark.catalog.tableExists("uber.bronze_new.bulk_rides"):
    df_spark.write.format("delta")\
        .mode("overwrite")\
        .saveAsTable(f"uber.bronze_new.bulk_rides")
    print("This will not run more than one time")
